# %% [markdown]
# <a href="https://colab.research.google.com/github/shiv4ngi/Task/blob/master/Logistic_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
#importing libraries


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#reading dataset

data = pd.read_csv('drive/My Drive/social_ad.csv')
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# 5    15728773    Male   27            58000          0
# 6    15694829  Female   32           150000          1
# 7    15600575    Male   25            33000          0
# 8    15727311  Female   35            65000          0
# 9    15570769  Female   26            80000          0
# 10   15606274  Female   26            52000          0
# 11   15746139    Male   20            86000          0
# 12   15704987    Male   32            18000          0
# 13   15628972    Male   31            82000          0
# 14   15697686    Male   29            80000          0
# 15   15733883    Male   47            25000          1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 5 columns):
# User ID            390 non-null int64
# Gender             390 non-null object
# Age                390 non-null int64
# EstimatedSalary    390 non-null int64
# Purchased          390 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 15.3+ KB

# %%
#removing any nan value

data.dropna(how='all')
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# 5    15728773    Male   27            58000          0
# 6    15694829  Female   32           150000          1
# 7    15600575    Male   25            33000          0
# 8    15727311  Female   35            65000          0
# 9    15570769  Female   26            80000          0
# 10   15606274  Female   26            52000          0
# 11   15746139    Male   20            86000          0
# 12   15704987    Male   32            18000          0
# 13   15628972    Male   31            82000          0
# 14   15697686    Male   29            80000          0
# 15   15733883    Male   47            25000          1
# ...

# %%
#splitting the data
X = data.iloc[:, [2, 3]].values
y = data.iloc[:, 4].values

# %%
# Splitting the dataset into the Training set and Test set

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# **Feature scaling**

# %%
#feature scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Logistic Regression Model Fitting

# %%
#fitting logistic regression on training dataset
lr = LogisticRegression(random_state = 0)
lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# **Predicting the test set results and calculating the accuracy**

# %%
#predicting the value of y
y_pred = lr.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(lr.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.85

# %% [markdown]
# **Accuracy of logistic regression classifier on test set: 0.85**

# %% [markdown]
# # **Confusion metrics**

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[59  7]
#  [ 8 24]]

# %% [markdown]
# **Confusion metrics is telling us that 59 +24 are correctly classified and 7+8 are incorrectly classified**.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89        66
#            1       0.77      0.75      0.76        32
#
#     accuracy                           0.85        98
#    macro avg       0.83      0.82      0.82        98
# weighted avg       0.85      0.85      0.85        98

# %% [markdown]
# So we can say that model works well on the train and test data as it has given a high value of accuracy ,precision and recall.
