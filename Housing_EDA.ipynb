# %% [markdown]
# <a href="https://colab.research.google.com/github/shiv4ngi/Task/blob/master/Housing_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA

# %% [markdown]
# Data Exploration
#
#
# Objective : try to understand the data. The objective of each variable.
# Perform Exploratory Data analysis on this dataset.
# Content
# Number of Instances: 506
#
# Attribute Information:
#
#
# 1.  CRIM: per capita crime rate by town
# 2.  ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3.  INDUS: proportion of non-retail business acres per town
# 4.  CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 5.  NOX: nitric oxides concentration (parts per 10 million)
# 6.  RM: average number of rooms per dwelling
# 7.  AGE: proportion of owner-occupied units built prior to 1940
# 8.  DIS: weighted distances to five Boston employment centres
# 9.  RAD: index of accessibility to radial highways
# 10.TAX: full-value property-tax rate per $10,000
# 11.   PTRATIO: pupil-teacher ratio by town
# 12.  B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
# 13.   LSTAT: % lower status of the population
# 14.   MEDV: Median value of owner-occupied homes in $1000's

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
house= pd.read_csv('drive/My Drive/hou_all.csv')
house
# Out:
#       0.00632    18   2.31  0  0.538  ...  15.3   396.9   4.98    24  1.1
# 0     0.02731   0.0   7.07  0  0.469  ...  17.8  396.90   9.14  21.6    1
# 1     0.02729   0.0   7.07  0  0.469  ...  17.8  392.83   4.03  34.7    1
# 2     0.03237   0.0   2.18  0  0.458  ...  18.7  394.63   2.94  33.4    1
# 3     0.06905   0.0   2.18  0  0.458  ...  18.7  396.90   5.33  36.2    1
# 4     0.02985   0.0   2.18  0  0.458  ...  18.7  394.12   5.21  28.7    1
# 5     0.08829  12.5   7.87  0  0.524  ...  15.2  395.60  12.43  22.9    1
# 6     0.14455  12.5   7.87  0  0.524  ...  15.2  396.90  19.15  27.1    1
# 7     0.21124  12.5   7.87  0  0.524  ...  15.2  386.63  29.93  16.5    1
# 8     0.17004  12.5   7.87  0  0.524  ...  15.2  386.71  17.10  18.9    1
# 9     0.22489  12.5   7.87  0  0.524  ...  15.2  392.52  20.45  15.0    1
# 10    0.11747  12.5   7.87  0  0.524  ...  15.2  396.90  13.27  18.9    1
# 11    0.09378  12.5   7.87  0  0.524  ...  15.2  390.50  15.71  21.7    1
# ...

# %%
house.columns =  ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV','a']

# %%
drop_cols= ['a']
house= house.drop(drop_cols , axis=1)

# %%
house.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.02731  0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 1  0.02729  0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 2  0.03237  0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 3  0.06905  0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# 4  0.02985  0.0   2.18     0  0.458  ...  222     18.7  394.12   5.21  28.7
#
# [5 rows x 14 columns]

# %%
house.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  505.000000  505.000000  505.000000  ...  505.000000  505.000000  505.000000
# mean     3.620667   11.350495   11.154257  ...  356.594376   12.668257   22.529901
# std      8.608572   23.343704    6.855868  ...   91.367787    7.139950    9.205991
# min      0.009060    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082210    0.000000    5.190000  ...  375.330000    7.010000   17.000000
# 50%      0.259150    0.000000    9.690000  ...  391.430000   11.380000   21.200000
# 75%      3.678220   12.500000   18.100000  ...  396.210000   16.960000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
# CRIM       505 non-null float64
# ZN         505 non-null float64
# INDUS      505 non-null float64
# CHAS       505 non-null int64
# NOX        505 non-null float64
# RM         505 non-null float64
# AGE        505 non-null float64
# DIS        505 non-null float64
# RAD        505 non-null int64
# TAX        505 non-null int64
# PTRATIO    505 non-null float64
# B          505 non-null float64
# LSTAT      505 non-null float64
# MEDV       505 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.3 KB

# %% [markdown]
# It tells us that their are no missing aur Nan values in the data.

# %%
house.min()
# Out:
# CRIM         0.00906
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# MEDV         5.00000
# dtype: float64

# %%
house.max()
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# MEDV        50.0000
# dtype: float64

# %%
house1=house[['NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV','CRIM']]
sns.pairplot(house1,height=1)

# %% [markdown]
# **Observation:-**
#
# If we do a univariate analysis on the variable CRIM we can see that their is an indirect relationship between CRIM and MEDV which is the output variable.
# As CRIM increases MEDV decreases

# %%
house_num= house.select_dtypes(include=['float64','int64'])
house_num.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.02731  0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 1  0.02729  0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 2  0.03237  0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 3  0.06905  0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# 4  0.02985  0.0   2.18     0  0.458  ...  222     18.7  394.12   5.21  28.7
#
# [5 rows x 14 columns]

# %%
#correlation with the variable
house_corr= house_num.corr()['AGE'][:-1]

# %%
house_corr
# Out:
# CRIM       0.352701
# ZN        -0.569524
# INDUS      0.645543
# CHAS       0.086461
# NOX        0.731461
# RM        -0.240211
# AGE        1.000000
# DIS       -0.747872
# RAD        0.456232
# TAX        0.506527
# PTRATIO    0.261724
# B         -0.273486
# LSTAT      0.602782
# Name: AGE, dtype: float64

# %%
plt.figure(figsize=(15,15))
ax = plt.subplot(2,2,1)
sns.kdeplot(house['CRIM'])
ax = plt.subplot(2,2,2)
sns.kdeplot(house['ZN'])
ax = plt.subplot(2,2,3)
sns.kdeplot(house['INDUS'])
ax = plt.subplot(2,2,4)
sns.kdeplot(house['CHAS'])

# %%
plt.figure(figsize=(15,15))
ax = plt.subplot(2,2,1)
sns.kdeplot(house['NOX'])
ax = plt.subplot(2,2,2)
sns.kdeplot(house['RM'])
ax = plt.subplot(2,2,3)
sns.kdeplot(house['DIS'])
ax = plt.subplot(2,2,4)
sns.kdeplot(house['AGE'])

# %%
plt.figure(figsize=(10,10))
ax = plt.subplot(2,3,1)
sns.kdeplot(house['RAD'])
ax = plt.subplot(2,3,2)
sns.kdeplot(house['TAX'])
ax = plt.subplot(2,3,3)
sns.kdeplot(house['PTRATIO'])
ax = plt.subplot(2,3,4)
sns.kdeplot(house['B'])
ax = plt.subplot(2,3,5)
sns.kdeplot(house['LSTAT'])
ax = plt.subplot(2,3,6)
sns.kdeplot(house['MEDV'])

# %% [markdown]
# **Box-plot**

# %%
box1=sns.boxplot(x='CRIM',y='AGE',data=house)

# %%
box2=sns.boxplot(x='CHAS',y='MEDV',data=house)

# %%
sns.regplot(house['CRIM'],house['AGE'])

# %%
sns.regplot(house['AGE'],house['MEDV'])

# %% [markdown]
# **Regression model**

# %%
x=house[['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','PTRATIO','B','LSTAT','MEDV']]
y=house['TAX']

# %%
#Importing the librabry and splitting the data into test and train

from sklearn.model_selection import train_test_split    
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Predicting the value of y

pred = lm.predict(x_test)

# %%
#plotting the scatter plot between the actual and the predicted value

plt.scatter(y_test,pred)

# %%
#import r2 score

from sklearn.metrics import r2_score

# %%
#checking the accuracy through r2score

print(r2_score(y_test,pred))
# Out:
# 0.8991675714271125
